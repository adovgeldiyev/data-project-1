# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
import seaborn as sns
from datetime import datetime
import os

# %%
file=os.path.join("..","Homework-07-Group Project","Stock Betas.csv")
stock_prices=os.path.join("..","Homework-07-Group Project","Stock Prices.csv")

# %%
# get SPF500 sector
stc_inst=pd.read_csv("Stock Betas.csv")
stc_nm=stc_inst["Security"]
# type(stc_nm)
stock_name=stc_nm.tolist()
stock_name
stc_inst.head()
# Out:
#   Security                Title                Industry  \
# 0      MMM           3M Company             Industrials
# 1      ABT  Abbott Laboratories             Health Care
# 2     ABBV          AbbVie Inc.             Health Care
# 3     ABMD          ABIOMED Inc             Health Care
# 4      ACN        Accenture plc  Information Technology
#
#             Headquarters Location         Date first added  Beta long term  \
# 0        Industrial Conglomerates      St. Paul, Minnesota            0.82
# 1           Health Care Equipment  North Chicago, Illinois            0.83
# 2                 Pharmaceuticals  North Chicago, Illinois            0.88
# 3           Health Care Equipment   Danvers, Massachusetts             NaN
# 4  IT Consulting & Other Services          Dublin, Ireland            1.03
#
#    Beta current time
# 0               0.59
# 1               0.52
# 2               0.79
# 3                NaN
# 4               1.00

# %%
fin_stc=stc_inst[stc_inst["Industry"]=="Financials"]
fin_lst=fin_stc["Security"].tolist()
fin_stc
# Out:
#     Security                              Title    Industry  \
# 10       AFL                          AFLAC Inc  Financials
# 23       ALL                      Allstate Corp  Financials
# 32       AXP                American Express Co  Financials
# 33       AIG       American International Group  Financials
# 36       AMP               Ameriprise Financial  Financials
# 44       AON                            Aon plc  Financials
# 53       AJG          Arthur J. Gallagher & Co.  Financials
# 54       AIZ                           Assurant  Financials
# 64       BAC               Bank of America Corp  Financials
# 65        BK  The Bank of New York Mellon Corp.  Financials
# 68     BRK.B                 Berkshire Hathaway  Financials
# 71       BLK                          BlackRock  Financials
# 85       COF              Capital One Financial  Financials
# 92      CBOE                Cboe Global Markets  Financials
# 101     SCHW         Charles Schwab Corporation  Financials
# 105       CB                      Chubb Limited  Financials
# 108     CINF               Cincinnati Financial  Financials
# 111        C                     Citigroup Inc.  Financials
# 112      CFG           Citizens Financial Group  Financials
# 115      CME                     CME Group Inc.  Financials
# 121      CMA                      Comerica Inc.  Financials
# 147      DFS        Discover Financial Services  Financials
# 161     ETFC                            E*Trade  Financials
# 179       RE              Everest Re Group Ltd.  Financials
# 191     FITB                Fifth Third Bancorp  Financials
# 193      FRC                First Republic Bank  Financials
# 205      BEN                 Franklin Resources  Financials
# 216       GL                    Globe Life Inc.  Financials
# 218       GS                Goldman Sachs Group  Financials
# 224      HIG         Hartford Financial Svc.Gp.  Financials
# ..       ...                                ...         ...
# 298        L                        Loews Corp.  Financials
# 301      MTB                     M&T Bank Corp.  Financials
# 304     MKTX                        MarketAxess  Financials
# 306      MMC                   Marsh & McLennan  Financials
# 316      MET                       MetLife Inc.  Financials
# 327      MCO                       Moody's Corp  Financials
# 328       MS                     Morgan Stanley  Financials
# 331     MSCI                           MSCI Inc  Financials
# 333     NDAQ                       Nasdaq, Inc.  Financials
# 348     NTRS               Northern Trust Corp.  Financials
# 370     PBCT          People's United Financial  Financials
# 379      PNC             PNC Financial Services  Financials
# 382      PFG          Principal Financial Group  Financials
# 384      PGR                  Progressive Corp.  Financials
# 386      PRU               Prudential Financial  Financials
# 396      RJF       Raymond James Financial Inc.  Financials
# 401       RF            Regions Financial Corp.  Financials
# 410     SPGI                   S&P Global, Inc.  Financials
# 427      STT                 State Street Corp.  Financials
# 430     SIVB                      SVB Financial  Financials
# 431      SYF                Synchrony Financial  Financials
# 435     TROW                T. Rowe Price Group  Financials
# 450      TRV       The Travelers Companies Inc.  Financials
# 451      TFC                   Truist Financial  Financials
# 456      USB                       U.S. Bancorp  Financials
# 465      UNM                         Unum Group  Financials
# 478      WRB          W. R. Berkley Corporation  Financials
# 486      WFC                        Wells Fargo  Financials
# 494     WLTW               Willis Towers Watson  Financials
# 503     ZION                      Zions Bancorp  Financials
#
#                 Headquarters Location               Date first added  \
# 10            Life & Health Insurance              Columbus, Georgia
# 23      Property & Casualty Insurance  Northfield Township, Illinois
# 32                   Consumer Finance             New York, New York
# 33      Property & Casualty Insurance             New York, New York
# 36   Asset Management & Custody Banks         Minneapolis, Minnesota
# 44                  Insurance Brokers         London, United Kingdom
# 53                  Insurance Brokers               Itasca, Illinois
# 54               Multi-line Insurance             New York, New York
# 64                  Diversified Banks      Charlotte, North Carolina
# 65   Asset Management & Custody Banks             New York, New York
# 68              Multi-Sector Holdings                Omaha, Nebraska
# 71   Asset Management & Custody Banks             New York, New York
# 85                   Consumer Finance        Tysons Corner, Virginia
# 92         Financial Exchanges & Data              Chicago, Illinois
# 101    Investment Banking & Brokerage      San Francisco, California
# 105     Property & Casualty Insurance            Zurich, Switzerland
# 108     Property & Casualty Insurance                Fairfield, Ohio
# 111                 Diversified Banks             New York, New York
# 112                    Regional Banks       Providence, Rhode Island
# 115        Financial Exchanges & Data              Chicago, Illinois
# 121                 Diversified Banks                  Dallas, Texas
# 147                  Consumer Finance           Riverwoods, Illinois
# 161    Investment Banking & Brokerage             New York, New York
# 179                       Reinsurance              Hamilton, Bermuda
# 191                    Regional Banks               Cincinnati, Ohio
# 193                    Regional Banks      San Francisco, California
# 205  Asset Management & Custody Banks          San Mateo, California
# 216           Life & Health Insurance                McKinney, Texas
# 218    Investment Banking & Brokerage             New York, New York
# 224     Property & Casualty Insurance          Hartford, Connecticut
# ..                                ...                            ...
# 298              Multi-line Insurance             New York, New York
# 301                    Regional Banks              Buffalo, New York
# 304        Financial Exchanges & Data             New York, New York
# 306                 Insurance Brokers             New York, New York
# 316           Life & Health Insurance             New York, New York
# 327        Financial Exchanges & Data             New York, New York
# 328    Investment Banking & Brokerage             New York, New York
# 331        Financial Exchanges & Data             New York, New York
# 333        Financial Exchanges & Data             New York, New York
# 348  Asset Management & Custody Banks              Chicago, Illinois
# 370        Thrifts & Mortgage Finance        Bridgeport, Connecticut
# 379                    Regional Banks       Pittsburgh, Pennsylvania
# 382           Life & Health Insurance               Des Moines, Iowa
# 384     Property & Casualty Insurance         Mayfield Village, Ohio
# 386           Life & Health Insurance             Newark, New Jersey
# 396    Investment Banking & Brokerage        St. Petersburg, Florida
# 401                    Regional Banks            Birmingham, Alabama
# 410        Financial Exchanges & Data             New York, New York
# 427  Asset Management & Custody Banks          Boston, Massachusetts
# 430                    Regional Banks        Santa Clara, California
# 431                  Consumer Finance          Stamford, Connecticut
# 435  Asset Management & Custody Banks            Baltimore, Maryland
# 450     Property & Casualty Insurance             New York, New York
# 451                    Regional Banks      Charlotte, North Carolina
# 456                 Diversified Banks         Minneapolis, Minnesota
# 465           Life & Health Insurance         Chattanooga, Tennessee
# 478     Property & Casualty Insurance         Greenwich, Connecticut
# 486                 Diversified Banks      San Francisco, California
# 494                 Insurance Brokers         London, United Kingdom
# 503                    Regional Banks           Salt Lake City, Utah
#
#      Beta long term  Beta current time
# 10              NaN                NaN
# 23             0.97               1.24
# 32             1.35               1.73
# 33             1.44               2.50
# 36              NaN                NaN
# 44              NaN                NaN
# 53              NaN                NaN
# 54              NaN                NaN
# 64             1.38               1.31
# 65             1.10               1.16
# 68              NaN                NaN
# 71             1.21               1.22
# 85             1.61               1.76
# 92              NaN                NaN
# 101             NaN                NaN
# 105             NaN                NaN
# 108             NaN                NaN
# 111            1.62               1.83
# 112             NaN                NaN
# 115             NaN                NaN
# 121             NaN                NaN
# 147             NaN                NaN
# 161             NaN                NaN
# 179             NaN                NaN
# 191             NaN                NaN
# 193             NaN                NaN
# 205             NaN                NaN
# 216             NaN                NaN
# 218            1.34               1.30
# 224             NaN                NaN
# ..              ...                ...
# 298             NaN                NaN
# 301             NaN                NaN
# 304             NaN                NaN
# 306             NaN                NaN
# 316            1.52               1.81
# 327             NaN                NaN
# 328            1.48               1.49
# 331             NaN                NaN
# 333             NaN                NaN
# 348             NaN                NaN
# 370             NaN                NaN
# 379             NaN                NaN
# 382             NaN                NaN
# 384             NaN                NaN
# 386             NaN                NaN
# 396             NaN                NaN
# 401             NaN                NaN
# 410             NaN                NaN
# 427             NaN                NaN
# 430             NaN                NaN
# 431             NaN                NaN
# 435             NaN                NaN
# 450             NaN                NaN
# 451             NaN                NaN
# 456            1.17               1.16
# 465             NaN                NaN
# 478             NaN                NaN
# 486            1.28               1.28
# 494             NaN                NaN
# 503             NaN                NaN
#
# [66 rows x 7 columns]

# %% [markdown]
# # Using API to pull the stock price

# %%
import pandas as pd
import requests

demo ='a74a4e302cd75c0ed624cacc4762e0e6'

companies = stock_name

listofdf = []



for item in companies:
    try:
        histprices = requests.get(f"https://fmpcloud.io/api/v3/historical-price-full/{item}?serietype=line&apikey={demo}")
        histprices = histprices.json()
        histprices = histprices['historical'][["date"]>="2020-02-28"]
        histpricesdf = pd.DataFrame.from_dict(histprices)
        histpricesdf = histpricesdf.rename({'close': item}, axis=1) 
        listofdf.append(histpricesdf)
    except Exception:
        pass

dfs = [df.set_index('date') for df in listofdf]
histpriceconcat = pd.concat(dfs,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8e999a119088> in <module>
#      12 for item in companies:
#      13     try:
# ---> 14         histprices = requests.get(f"https://fmpcloud.io/api/v3/historical-price-full/{item}?serietype=line&apikey={demo}")
#      15         histprices = histprices.json()
#      16         histprices = histprices['historical'][["date"]>="2020-02-28"]
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# C:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55     family = allowed_gai_family()
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#      59         sock = None
#
# C:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     746     # and socket type values to enum constants.
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#     750         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
# print(json.dumps(histprices, indent=4))

# %%
# histpriceconcat.reset_index(inplace=True)
# histpriceconcat.rename(columns={"index":"date"},inplace=True)
# # histpriceconcat

# %%
# his_smp=histpriceconcat[(histpriceconcat["date"]>="2020-02-28") &(histpriceconcat["date"]<="2020-04-9")]
# his_smp

# %%
stock_price=pd.read_csv("Stock Prices.csv")
# stock_price.set_index("Date")

# %%
stock_price.head()
# Out:
#         Date          A        AAL         AAP        AAPL       ABBV  \
# 0  1/31/2020  82.350426  26.741179  131.378830  308.777191  79.829422
# 1   2/3/2020  81.941467  27.059999  132.276291  307.929199  81.090614
# 2   2/4/2020  83.307983  28.430000  131.189362  318.095062  83.120338
# 3   2/5/2020  84.714409  29.100000  136.633987  320.688934  85.356979
# 4   2/6/2020  84.604691  28.299999  133.991440  324.440002  85.898903
#
#          ABC        ABMD        ABT         ACN  ...     XLNX.5       XOM.5  \
# 0  85.184814  186.289993  86.774590  204.288239  ...  5043400.0  34282900.0
# 1  85.324196  185.949997  86.694923  206.866592  ...  4640600.0  27397300.0
# 2  87.703720  190.899994  87.860023  211.575348  ...  3275900.0  31922100.0
# 3  91.039032  190.729996  89.184441  211.266739  ...  3477000.0  32099200.0
# 4  92.074471  196.009995  89.094818  213.198029  ...  2777400.0  16055400.0
#
#       XRAY.5      XRX.5      XYL.5      YUM.5      ZBH.5    ZBRA.5     ZION.5  \
# 0  1625800.0  2335900.0  1553200.0  2117400.0  1407700.0  335900.0  1880800.0
# 1  1324000.0  1839500.0  1259300.0  1671000.0  1905600.0  262400.0  2642600.0
# 2  1081700.0  2661900.0  1380900.0  1595500.0  3068300.0  251100.0  2292300.0
# 3  1084000.0  2328500.0  1803700.0  1814400.0  1364100.0  244200.0  2326100.0
# 4   938400.0  2313700.0  5052400.0  3271600.0  1185700.0  407500.0  2144200.0
#
#        ZTS.5
# 0  2582300.0
# 1  2377000.0
# 2  1839800.0
# 3  1507600.0
# 4  2206800.0
#
# [5 rows x 3031 columns]

# %%
sub_stock=pd.DataFrame(stock_price,columns=stock_name)
sub_stock["date"]=stock_price["Date"]
sub_st=sub_stock.set_index("date")
sub_st.head()
stc_chg=sub_st.pct_change()

stc_chg.drop(stc_chg.index[0],inplace=True)
stc_chg.head()
# Out:
#                MMM       ABT      ABBV      ABMD       ACN      ATVI  \
# date
# 2/3/2020 -0.013047 -0.000918  0.015799 -0.001825  0.012621 -0.004617
# 2/4/2020  0.004151  0.013439  0.025030  0.026620  0.022762  0.017179
# 2/5/2020  0.032371  0.015074  0.026908 -0.000891 -0.001459 -0.006080
# 2/6/2020  0.003450 -0.001005  0.006349  0.027683  0.009141  0.023959
# 2/7/2020 -0.017251 -0.017883  0.058614 -0.046426 -0.012047  0.021075
#
#               ADBE       AMD       AAP       AES  ...      WYNN       XEL  \
# date                                              ...
# 2/3/2020  0.019536  0.021702  0.006831  0.022659  ...  0.019182  0.003758
# 2/4/2020  0.024413  0.029779 -0.008217  0.014771  ...  0.032042 -0.002160
# 2/5/2020 -0.003245  0.007887  0.041502  0.007278  ... -0.003165  0.000000
# 2/6/2020  0.005225 -0.010433 -0.019340 -0.008671  ...  0.014439  0.000000
# 2/7/2020 -0.003728  0.008313 -0.010717 -0.003887  ... -0.054251 -0.008514
#
#                XRX      XLNX       XYL       YUM      ZBRA       ZBH  \
# date
# 2/3/2020  0.020242  0.006747  0.020573  0.006051  0.014769  0.004124
# 2/4/2020  0.007716  0.008583  0.038037  0.002819  0.021934  0.055619
# 2/5/2020  0.028712  0.028561  0.012715  0.000656 -0.000242  0.005932
# 2/6/2020  0.001595 -0.005780 -0.051250 -0.028470  0.017271  0.008307
# 2/7/2020 -0.013535 -0.023940  0.012993 -0.016387 -0.019160 -0.016477
#
#               ZION       ZTS
# date
# 2/3/2020  0.013629  0.009761
# 2/4/2020  0.012362  0.025458
# 2/5/2020  0.028492 -0.007772
# 2/6/2020 -0.020829  0.007832
# 2/7/2020 -0.016592 -0.000504
#
# [5 rows x 505 columns]

# %%
sub_st.head()
# Out:
#                   MMM        ABT       ABBV        ABMD         ACN  \
# date
# 1/31/2020  157.236130  86.774590  79.829422  186.289993  204.288239
# 2/3/2020   155.184692  86.694923  81.090614  185.949997  206.866592
# 2/4/2020   155.828873  87.860023  83.120338  190.899994  211.575348
# 2/5/2020   160.873184  89.184441  85.356979  190.729996  211.266739
# 2/6/2020   161.428162  89.094818  85.898903  196.009995  213.198029
#
#                 ATVI        ADBE        AMD         AAP        AES  ...  \
# date                                                                ...
# 1/31/2020  58.097900  351.140015  47.000000  131.378830  19.860001  ...
# 2/3/2020   57.829662  358.000000  48.020000  132.276291  20.309999  ...
# 2/4/2020   58.823128  366.739990  49.450001  131.189362  20.610001  ...
# 2/5/2020   58.465481  365.549988  49.840000  136.633987  20.760000  ...
# 2/6/2020   59.866268  367.459992  49.320000  133.991440  20.580000  ...
#
#                  WYNN        XEL        XRX       XLNX        XYL         YUM  \
# date
# 1/31/2020  125.110161  68.744751  35.117916  84.114929  81.408234  105.298073
# 2/3/2020   127.510017  69.003075  35.828766  84.682465  83.083054  105.935226
# 2/4/2020   131.595734  68.854042  36.105206  85.409309  86.243279  106.233887
# 2/5/2020   131.179230  68.854042  37.141857  87.848724  87.339890  106.303574
# 2/6/2020   133.073334  68.854042  37.201096  87.340927  82.863731  103.277138
#
#                  ZBRA         ZBH       ZION         ZTS
# date
# 1/31/2020  239.020004  147.533401  45.155808  133.993210
# 2/3/2020   242.550003  148.141892  45.771252  135.301086
# 2/4/2020   247.869995  156.381439  46.337063  138.745514
# 2/5/2020   247.809998  157.309128  47.657288  137.667252
# 2/6/2020   252.089996  158.615875  46.664635  138.745514
#
# [5 rows x 505 columns]

# %%
stc_chg=stc_chg.T
stc_chg.reset_index(inplace=True)
stc_chg.rename(columns={"index":"Ticker"},inplace=True)
stc_chg.head(5)
# Out:
# date Ticker  2/3/2020  2/4/2020  2/5/2020  2/6/2020  2/7/2020  2/10/2020  \
# 0       MMM -0.013047  0.004151  0.032371  0.003450 -0.017251   0.000437
# 1       ABT -0.000918  0.013439  0.015074 -0.001005 -0.017883   0.004894
# 2      ABBV  0.015799  0.025030  0.026908  0.006349  0.058614   0.026655
# 3      ABMD -0.001825  0.026620 -0.000891  0.027683 -0.046426  -0.068643
# 4       ACN  0.012621  0.022762 -0.001459  0.009141 -0.012047   0.004585
#
# date  2/11/2020  2/12/2020  2/13/2020  ...  3/31/2020  4/1/2020  4/2/2020  \
# 0      0.014362   0.008310  -0.015832  ...  -0.008930 -0.024687  0.035827
# 1      0.009853  -0.004261  -0.001239  ...  -0.005420 -0.029654  0.037482
# 2      0.013193   0.018646  -0.024951  ...   0.012626 -0.036357  0.023291
# 3      0.009995  -0.050506  -0.012819  ...  -0.025706 -0.004685 -0.008306
# 4     -0.001929  -0.000707   0.001934  ...  -0.038629 -0.052554  0.010279
#
# date  4/3/2020  4/6/2020  4/7/2020  4/8/2020  4/9/2020  4/13/2020  4/14/2020
# 0    -0.029875  0.051648  0.027719  0.030360 -0.008121  -0.009338        0.0
# 1     0.000126  0.041284 -0.009670  0.036861  0.012831  -0.002208        0.0
# 2    -0.023426  0.032166 -0.004490  0.042048  0.015148   0.006897        0.0
# 3    -0.013121  0.062659  0.016771  0.022843  0.024381  -0.023051        0.0
# 4    -0.026365  0.091357 -0.011623  0.046368  0.036045  -0.030070        0.0
#
# [5 rows x 51 columns]

# %%
stcchg_ind=stc_chg.merge(stc_inst, left_on="Ticker",right_on="Security")
stcchg_avg=stcchg_ind.groupby("Industry").sum()
stcchg_avg=stcchg_avg.T
stcchg_avg.sample()
# Out:
# Industry  Communication Services  Consumer Discretionary  Consumer Staples  \
# 2/4/2020                0.386312                1.027047          0.147749
#
# Industry    Energy  Financials  Health Care  Industrials  \
# 2/4/2020  0.300582    0.735834     1.033679     1.408823
#
# Industry  Information Technology  Materials  Real Estate  Utilities
# 2/4/2020                1.581504    0.60457     0.368461  -0.255911

# %%
stcchg_ind=stc_chg.merge(stc_inst, left_on="Ticker",right_on="Security")
stcchg_avg=stcchg_ind.groupby("Industry").mean()
stcchg_avg=stcchg_avg.T
stcchg_avg.sample()
# Out:
# Industry   Communication Services  Consumer Discretionary  Consumer Staples  \
# 2/13/2020               -0.003035               -0.005876          0.001283
#
# Industry     Energy  Financials  Health Care  Industrials  \
# 2/13/2020 -0.004638    0.001417    -0.002355    -0.005733
#
# Industry   Information Technology  Materials  Real Estate  Utilities
# 2/13/2020                -0.00028  -0.011162     0.007108   0.009081

# %%
barplot=stcchg_avg.plot.line()

# %% [markdown]
# # Boxplots for different sectors

# %%
plt.figure(figsize=(20,10))
stcchg_avg.boxplot()

# %%
stcchg_avg.bar(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f62ade0822cf> in <module>
# ----> 1 stcchg_avg.bar(figsize=(15,10))
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %% [markdown]
# # Financials Industry outliers

# %%
fin_stc=stcchg_ind[stcchg_ind["Industry"]=="Financials"]
fin_stc.set_index("Ticker",inplace=True)
# fin_stc_T=fin_stc.T
# fin_stc_T.drop(fin_stc_T.index[-3:],inplace=True)
# fin_stc_T.plot(figsize=(15,10))
# fin_stc["max"]=fin_stc.max(axis=1)
# fin_stc["min"]=fin_stc.min(axis=1)
# fin_stc["max"].max()
# #      # Lincoln National
# fin_chg_max.loc["0.3170028472340416"]
fin_wk=fin_stc.loc[["AON","CB","FRC","LNC","NTRS","SIVB","ZION"],["3/9/20","3/10/20","3/11/20","3/12/20","3/13/20","3/16/20"]]
# # fin_stc["Chg_sum"]=fin_stc.sum(axis=1)
# # print(fin_stc.max())
# # print(fin_stc.min())
fin_wk.T.plot(figsize=(15,10))

# # lnc_stc=fin_stc.loc["LNC"]
# # type(lnc_stc)
# # T.plot(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-5c25374e2815> in <module>
#       9 # #      # Lincoln National
#      10 # fin_chg_max.loc["0.3170028472340416"]
# ---> 11 fin_wk=fin_stc.loc[["AON","CB","FRC","LNC","NTRS","SIVB","ZION"],["3/9/20","3/10/20","3/11/20","3/12/20","3/13/20","3/16/20"]]
#      12 # # fin_stc["Chg_sum"]=fin_stc.sum(axis=1)
#      13 # # print(fin_stc.max())
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     875         # ugly hack for GH #836
#     876         if self._multi_take_opportunity(tup):
# --> 877             return self._multi_take(tup)
#     878
#     879         # no shortcut needed
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#     932         o = self.obj
#     933         d = {axis: self._get_listlike_indexer(key, axis)
# --> 934              for (key, axis) in zip(tup, o._AXIS_ORDERS)}
#     935         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#     936
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#     932         o = self.obj
#     933         d = {axis: self._get_listlike_indexer(key, axis)
# --> 934              for (key, axis) in zip(tup, o._AXIS_ORDERS)}
#     935         return o._reindex_with_indexers(d, copy=True, allow_dups=True)
#     936
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/16/20'], dtype='object')] are in the [columns]"

# %%
# sub_stc=sub_st.T
# sub_log=np.log(sub_stc)
# sub_log
# sub_log.reset_index(inplace=True)
# sub_log.rename(columns={"index":"Ticker"},inplace=True)

# %%
# stclog_ind=sub_log.merge(stc_inst, left_on="Ticker",right_on="Security")
# stclog_avg=stclog_ind.groupby("Industry").mean()
# stclog_avg=stclog_avg.T
# # stclog_avg.head()
# sns.pairplot(stclog_avg)
# # plt.show()

# %% [markdown]
# # CDC data

# %%
cdc_data=pd.read_csv("/Users/yxair/Desktop/NW Bootbcamps/HW/Group Project/us-counties.csv")
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
cdc_smp1=cdc_data[cdc_data["date"]>="2020-02-03"]  # &(cdc_data["date"]<="2020-04-9")
cdc_smp2=cdc_smp1[["date","cases","deaths"]]
cdc_smp3=cdc_smp2.groupby("date").sum()
cdc_smp3.reset_index(inplace=True)
cdc_smp3
cdc_smp3["date"])
# Out:
# pandas.core.series.Series

# %%
sub_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Columns: 506 entries, MMM to date
# dtypes: float64(505), object(1)
# memory usage: 197.8+ KB

# %%
cdc_smp3.sample()
# Out:
#          date  cases  deaths
# 5  2020-02-08     12       0

# %%
cdc_smp3.info()
cdc_smp3["date"] = pd.to_datetime(cdc_smp3["date"]).dt.strftime('%m/%d/%Y')
cdc_smp3.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    71 non-null     object
#  1   cases   71 non-null     int64
#  2   deaths  71 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.8+ KB
#           date  cases  deaths
# 23  02/26/2020     60       0

# %%
sub_stock["date"] = pd.to_datetime(sub_stock["date"]).dt.strftime('%m/%d/%Y')
merge_data=sub_stock.merge(cdc_smp3,left_on="date", right_on="date",how="left")
merge_data=merge_data.fillna(0)
merge_data.head()
# Out:
#           MMM        ABT       ABBV        ABMD         ACN       ATVI  \
# 0  157.236130  86.774590  79.829422  186.289993  204.288239  58.097900
# 1  155.184692  86.694923  81.090614  185.949997  206.866592  57.829662
# 2  155.828873  87.860023  83.120338  190.899994  211.575348  58.823128
# 3  160.873184  89.184441  85.356979  190.729996  211.266739  58.465481
# 4  161.428162  89.094818  85.898903  196.009995  213.198029  59.866268
#
#          ADBE        AMD         AAP        AES  ...       XLNX        XYL  \
# 0  351.140015  47.000000  131.378830  19.860001  ...  84.114929  81.408234
# 1  358.000000  48.020000  132.276291  20.309999  ...  84.682465  83.083054
# 2  366.739990  49.450001  131.189362  20.610001  ...  85.409309  86.243279
# 3  365.549988  49.840000  136.633987  20.760000  ...  87.848724  87.339890
# 4  367.459992  49.320000  133.991440  20.580000  ...  87.340927  82.863731
#
#           YUM        ZBRA         ZBH       ZION         ZTS        date  \
# 0  105.298073  239.020004  147.533401  45.155808  133.993210  01/31/2020
# 1  105.935226  242.550003  148.141892  45.771252  135.301086  02/03/2020
# 2  106.233887  247.869995  156.381439  46.337063  138.745514  02/04/2020
# 3  106.303574  247.809998  157.309128  47.657288  137.667252  02/05/2020
# 4  103.277138  252.089996  158.615875  46.664635  138.745514  02/06/2020
#
#    cases  deaths
# 0    0.0     0.0
# 1   11.0     0.0
# 2   11.0     0.0
# 3   12.0     0.0
# 4   12.0     0.0
#
# [5 rows x 508 columns]

# %%
# merge_data["avg_stc"]= (merge_data["GOOG"] + merge_data["F"] + merge_data["MSFT"])/3
# merge_data.head(5)

# %%
aap_stc = merge_data.iloc[:,8]
cases = merge_data.iloc[:,-2]
correlation = st.pearsonr(cases,aap_stc)
plt.scatter(cases,aap_stc)
plt.xlabel('case')
plt.ylabel("cdc case and AAP stock price")
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is -0.46

# %%
plt.figure(figsize=(12,6))
plt.title('Downtrend of AAP stock during the COVID-19', size=14)
merge_data["AAP"].rolling(window=10).mean().plot(label='30 Day Mean')
merge_data["AAP"].plot(label='GOOG')
plt.legend()
plt.show()
# .loc['2020-02-28':'2020-04-09']

# %%
# plt.figure(figsize=(12,6))
# plt.title('Stock Prices and CDC cases', size=14)
# merge_data["AAP"].rolling(window=10).mean().plot(label='AAP MEAN')
# merge_data["cases"].plot(label='cases')
# # plt.legend()
# # plt.show()

# %%
fig2 = plt.figure()

plt.plot_date(merge_data["date"], merge_data["cases"])
plt.plot_date(merge_data["date"], merge_data["AAP"], secondary_y=True)

fig2.autofmt_xdate()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-313-044d5e82cbdb> in <module>
#       2
#       3 plt.plot_date(merge_data["date"], merge_data["cases"])
# ----> 4 plt.plot_date(merge_data["date"], merge_data["AAP"], secondary_y=True)
#       5
#       6 fig2.autofmt_xdate()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot_date(x, y, fmt, tz, xdate, ydate, data, **kwargs)
#    2804     return gca().plot_date(
#    2805         x, y, fmt=fmt, tz=tz, xdate=xdate, ydate=ydate, **({"data":
# -> 2806         data} if data is not None else {}), **kwargs)
#    2807
#    2808
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot_date(self, x, y, fmt, tz, xdate, ydate, **kwargs)
#    1740             self.yaxis_date(tz)
#    1741
# -> 1742         ret = self.plot(x, y, fmt, **kwargs)
#    1743
#    1744         self.autoscale_view()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     403                 "non-matching shapes is deprecated.")
#     404         for j in range(max(ncx, ncy)):
# --> 405             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     406             ret.append(seg)
#     407         return ret
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Line2D' object has no property 'secondary_y'

# %%
plt.figure(figsize=(20,10))
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('cases', color=color)
ax1.plot_date(merge_data["date"], merge_data["cases"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

plt.xticks(rotation=90)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('AAP', color=color)  # we already handled the x-label with ax1
ax2.plot_date(merge_data["date"], merge_data["AAP"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
